# %%
from urllib.request import urlopen
import time
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

url = "https://map.naver.com/v5/?c=14139888.0710906,4507920.1560387,15,0,0,0,dh"
driver = webdriver.Chrome("e:/chromedriver_win32/chromedriver.exe")
driver.get(url)

# 음식점 검색

elem=driver.find_element_by_class_name("input_search")
elem.send_keys('음식점')
time.sleep(2)
elem.send_keys(Keys.ENTER)
time.sleep(3)
driver.switch_to.frame("searchIframe")
r = driver.page_source
soup = BeautifulSoup(r, "html.parser")

# 리뷰 순으로 정렬

filter_btn1 = driver.find_element_by_css_selector('#app-root > div > div._3wTZJ._2X43I > div > div > div > span:nth-child(2) > a')
filter_btn1.click()
time.sleep(3)
filter_btn1 = driver.find_element_by_css_selector('#app-root > div > div._3wTZJ._2X43I > div._1aXbD > div > ul > li:nth-child(3) > a')
filter_btn1.click()
time.sleep(3)


tnums = [1, 2, 4, 5]
for t in tnums: 
    # 필터 선택
    filter_btn = driver.find_element_by_css_selector('._1qriX')
    filter_btn.click()
    time.sleep(3)

    # 음식종류 선택
    rf_btn = driver.find_element_by_css_selector('#modal-root > div > div > div > header > a._1b1Sc > svg')
    rf_btn.click()
    time.sleep(3)
    fs_btn = driver.find_element_by_xpath('//*[@id="modal-root"]/div/div/div/div[1]/div/div/ul/li[1]/div/a[{}]'.format(t))
    fs_btn.click()
    time.sleep(3)
    foodspec = driver.find_element_by_xpath('//*[@id="modal-root"]/div/div/div/div[1]/div/div/ul/li[1]/div/a[{}]'.format(t))
    fds = foodspec.text

    # 적용
    apply_btn = driver.find_element_by_css_selector('#modal-root > div > div > div > div._3GN6y > a._3TurT._3hOhO')
    apply_btn.click()
    time.sleep(3)

    # 5개의 음식점 출력 for문
    numbers = [1, 2, 3, 4, 5]

    for i in numbers:
        select_btn = driver.find_element_by_css_selector('#_pcmap_list_scroll_container > ul > li:nth-child({}) > div._3hn9q > a > div.O9Z-o > div > span.OXiLu'.format(i))
        select_btn.click()
        time.sleep(3)
    
        #iframe을 옮기기
        driver.switch_to.default_content()
        driver.switch_to.frame("entryIframe")
        time.sleep(3)
    
        # 스크롤 이동
        driver.execute_script("window.scrollTo(0, 900)")
        time.sleep(3)
        driver.execute_script("window.scrollTo(0, 2150)")
        time.sleep(3) 
        driver.execute_script("window.scrollTo(0, 2800)")
        time.sleep(3)
        driver.execute_script("window.scrollTo(0, 900)")
        time.sleep(3)
    
        tmp_str1 = driver.find_element_by_css_selector('#app-root > div > div > div.place_detail_wrapper > div:nth-child(5) > div > div.place_section.nQcjn > h2 > em')
        tmp_str2 = driver.find_element_by_css_selector('#app-root > div > div > div.place_detail_wrapper > div:nth-child(5) > div > div:nth-child(8) > h2 > em')
        a = tmp_str1.text 
        b = tmp_str2.text
        c = a.replace(",","")
        d = b.replace(",","")
        x = int(c)
        z = int(d)
        
        try:
            select_btn = driver.find_element_by_class_name('_3iTUo')
            select_btn.click()
            time.sleep(3)   

            # 반복문
            y = 0
            y < 100
            while True:
                try:
                    y += 1
                    a = driver.find_element_by_css_selector('#app-root > div > div > div.place_detail_wrapper > div:nth-child(5) > div > div.place_section.no_margin > div > ul > li:nth-child({}) > a > div._2CZ7z'.format(y))
                    restaurant = driver.find_element_by_class_name('_2msz7')
                    res = restaurant.text
                    q = 'https://map.naver.com/v5/search/{}'.format(res)
                    p = q.replace(" ", "_")
                    menus = driver.find_element_by_css_selector('#app-root > div > div > div.place_detail_wrapper > div:nth-child(5) > div > div.place_section.no_margin > div > ul > li:nth-child({}) > a > div._2CZ7z > div._25ryC'.format(y))
                    prices = driver.find_element_by_css_selector('#app-root > div > div > div.place_detail_wrapper > div:nth-child(5) > div > div.place_section.no_margin > div > ul > li:nth-child({}) > a > div._2CZ7z > div._3qFuX'.format(y))
                    
                    # 크롤링 데이터 출력
                    print("{}, {}, {}, {}, {}".format(fds, res, menus.text, prices.text, (x+ z)))
                    print(p)
                except:
                    break
        
            driver.switch_to.default_content()
            driver.switch_to.frame("searchIframe")       
            time.sleep(3)  
            
        # 메뉴버튼이 없을때 수행할 반복문
        except:
            y2 = 1
            y2 < 100
            while True:
                try:
                    y2 += 1
                    restaurant = driver.find_element_by_class_name('_2msz7')                    
                    res = restaurant.text
                    q = 'https://map.naver.com/v5/search/{}'.format(res)
                    p = q.replace(" ", "_")
                    menus2 = driver.find_element_by_css_selector('#app-root > div > div > div.place_detail_wrapper > div:nth-child(5) > div > div:nth-child(2) > div > ul > li:nth-child({}) > a > div._1hkqi > div._1tQLX > div'.format(y2))
                    prices2 = driver.find_element_by_css_selector('#app-root > div > div > div.place_detail_wrapper > div:nth-child(5) > div > div:nth-child(2) > div > ul > li:nth-child({}) > a > div._1hkqi > div._3IAAc > div'.format(y2))
                    # 크롤링 데이터 출력
                    print("{}, {}, {}, {}, {}".format(fds, res, menus2.text, prices2.text, (x+ z)))
                    print(p)
                except:
                    break
# Out:
# C:\Users\BIT\AppData\Local\Temp/ipykernel_13464/1060130730.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome("e:/chromedriver_win32/chromedriver.exe")
# C:\Users\BIT\AppData\Local\Temp/ipykernel_13464/1060130730.py:15: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   elem=driver.find_element_by_class_name("input_search")
# C:\Users\BIT\AppData\Local\Temp/ipykernel_13464/1060130730.py:32: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   filter_btn1 = driver.find_element_by_css_selector('#app-root > div > div._3wTZJ._2X43I > div > div > div > span:nth-child(2) > a')
# C:\Users\BIT\AppData\Local\Temp/ipykernel_13464/1060130730.py:37: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   filter_btn1 = driver.find_element_by_css_selector('#app-root > div > div._3wTZJ._2X43I > div._1aXbD > div > ul > li:nth-child(3) > a')
# C:\Users\BIT\AppData\Local\Temp/ipykernel_13464/1060130730.py:45: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   filter_btn = driver.find_element_by_css_selector('._1qriX')
# C:\Users\BIT\AppData\Local\Temp/ipykernel_13464/1060130730.py:50: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   rf_btn = driver.find_element_by_css_selector('#modal-root > div > div > div > header > a._1b1Sc > svg')
# C:\Users\BIT\AppData\Local\Temp/ipykernel_13464/1060130730.py:53: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   fs_btn = driver.find_element_by_xpath('//*[@id="modal-root"]/div/div/div/div[1]/div/div/ul/li[1]/div/a[{}]'.format(t))
# C:\Users\BIT\AppData\Local\Temp/ipykernel_13464/1060130730.py:56: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   foodspec = driver.find_element_by_xpath('//*[@id="modal-root"]/div/div/div/div[1]/div/div/ul/li[1]/div/a[{}]'.format(t))
# C:\Users\BIT\AppData\Local\Temp/ipykernel_13464/1060130730.py:60: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   apply_btn = driver.find_element_by_css_selector('#modal-root > div > div > div > div._3GN6y > a._3TurT._3hOhO')
# C:\Users\BIT\AppData\Local\Temp/ipykernel_13464/1060130730.py:68: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   select_btn = driver.find_element_by_css_selector('#_pcmap_list_scroll_container > ul > li:nth-child({}) > div._3hn9q > a > div.O9Z-o > div > span.OXiLu'.format(i))
# C:\Users\BIT\AppData\Local\Temp/ipykernel_13464/1060130730.py:87: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   tmp_str1 = driver.find_element_by_css_selector('#app-root > div > div > div.place_detail_wrapper > div:nth-child(5) > div > div.place_section.nQcjn > h2 > em')
# C:\Users\BIT\AppData\Local\Temp/ipykernel_13464/1060130730.py:88: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   tmp_str2 = driver.find_element_by_css_selector('#app-root > div > div > div.place_detail_wrapper > div:nth-child(5) > div > div:nth-child(8) > h2 > em')
# C:\Users\BIT\AppData\Local\Temp/ipykernel_13464/1060130730.py:96: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   select_btn = driver.find_element_by_class_name('_3iTUo')
# C:\Users\BIT\AppData\Local\Temp/ipykernel_13464/1060130730.py:109: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   a = driver.find_element_by_css_selector('#app-root > div > div > div.place_detail_wrapper > div:nth-child(5) > div > div.place_section.no_margin > div > ul > li:nth-child({}) > a > div._2CZ7z'.format(y))
# C:\Users\BIT\AppData\Local\Temp/ipykernel_13464/1060130730.py:110: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   restaurant = driver.find_element_by_class_name('_2msz7')
# C:\Users\BIT\AppData\Local\Temp/ipykernel_13464/1060130730.py:111: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   menus = driver.find_element_by_css_selector('#app-root > div > div > div.place_detail_wrapper > div:nth-child(5) > div > div.place_section.no_margin > div > ul > li:nth-child({}) > a > div._2CZ7z > div._25ryC'.format(y))
# C:\Users\BIT\AppData\Local\Temp/ipykernel_13464/1060130730.py:112: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   prices = driver.find_element_by_css_selector('#app-root > div > div > div.place_detail_wrapper > div:nth-child(5) > div > div.place_section.no_margin > div > ul > li:nth-child({}) > a > div._2CZ7z > div._3qFuX'.format(y))
# 한식, 장꼬방묵은김치찌개전문, 장꼬방찌개, 9,000원, 2525명
# https://map.naver.com/v5/search/장꼬방묵은김치찌개전문
# 한식, 장꼬방묵은김치찌개전문, 계란말이, 9,000원, 2525명
# https://map.naver.com/v5/search/장꼬방묵은김치찌개전문
# 한식, 장꼬방묵은김치찌개전문, 장꼬방구이, 10,000원, 2525명
# https://map.naver.com/v5/search/장꼬방묵은김치찌개전문
# 한식, 장꼬방묵은김치찌개전문, 장꼬방찌개(포장), 8,000원, 2525명
# https://map.naver.com/v5/search/장꼬방묵은김치찌개전문
# 한식, 장꼬방묵은김치찌개전문, 계란말이포장), 9,000원, 2525명
# https://map.naver.com/v5/search/장꼬방묵은김치찌개전문
# 한식, 창고43 강남점, 창고43 스페셜, 43,000원, 2488명
# https://map.naver.com/v5/search/창고43_강남점
# 한식, 창고43 강남점, 창고43 설화등심, 59,000원, 2488명
# https://map.naver.com/v5/search/창고43_강남점
# 한식, 창고43 강남점, 창고43 특안심, 57,000원, 2488명
# https://map.naver.com/v5/search/창고43_강남점
# 한식, 창고43 강남점, 창고43 새우살, 67,000원, 2488명
# https://map.naver.com/v5/search/창고43_강남점
# 한식, 창고43 강남점, 창고43 도시락, 40,000원, 2488명
# https://map.naver.com/v5/search/창고43_강남점
# 한식, 창고43 강남점, 창고43세트, 125,000원, 2488명
# https://map.naver.com/v5/search/창고43_강남점
# 한식, 창고43 강남점, 와인세트, 160,000원, 2488명
# https://map.naver.com/v5/search/창고43_강남점
# 한식, 창고43 강남점, 한우명작모듬, 180,000원, 2488명
# https://map.naver.com/v5/search/창고43_강남점
# 한식, 창고43 강남점, 수제육포 선물세트(6ea), 50,000원, 2488명
# https://map.naver.com/v5/search/창고43_강남점
# 한식, 창고43 강남점, 수제육포 선물세트(10ea), 100,000원, 2488명
# https://map.naver.com/v5/search/창고43_강남점
# 한식, 창고43 강남점, 양념갈비 선물세트, 300,000원, 2488명
# https://map.naver.com/v5/search/창고43_강남점
# 한식, 창고43 강남점, 무쇠철판 양념 소갈비, 39,000원, 2488명
# https://map.naver.com/v5/search/창고43_강남점
# 한식, 두껍삼 강남직영점, 숙성 삼겹살 (150g)
# 대표, 18,000원, 1973명
# https://map.naver.com/v5/search/두껍삼_강남직영점
# 한식, 두껍삼 강남직영점, 한우 스페셜
# 대표, 143,000원, 1973명
# https://map.naver.com/v5/search/두껍삼_강남직영점
# 한식, 두껍삼 강남직영점, 숙성 목살 (150g), 18,000원, 1973명
# https://map.naver.com/v5/search/두껍삼_강남직영점
# 한식, 두껍삼 강남직영점, 숙성 목살 불고기 (180g), 21,000원, 1973명
# https://map.naver.com/v5/search/두껍삼_강남직영점
# 한식, 두껍삼 강남직영점, 숙성 가브리살 (130g), 20,000원, 1973명
# https://map.naver.com/v5/search/두껍삼_강남직영점
# 한식, 두껍삼 강남직영점, 숙성 항정살 (130g), 20,000원, 1973명
# https://map.naver.com/v5/search/두껍삼_강남직영점
# 한식, 두껍삼 강남직영점, 특수부위 (숙성 가브리살 65g + 숙성 항정살 65g), 20,000원, 1973명
# https://map.naver.com/v5/search/두껍삼_강남직영점
# 한식, 두껍삼 강남직영점, 광양 불고기 (180g), 35,000원, 1973명
# https://map.naver.com/v5/search/두껍삼_강남직영점
# 한식, 두껍삼 강남직영점, 한우 불고기 (180g), 42,000원, 1973명
# https://map.naver.com/v5/search/두껍삼_강남직영점
# 한식, 두껍삼 강남직영점, 한우 숙성 등심 (150g), 41,000원, 1973명
# https://map.naver.com/v5/search/두껍삼_강남직영점
# 한식, 두껍삼 강남직영점, 한우 숙성 채끝등심 (150g), 41,000원, 1973명
# https://map.naver.com/v5/search/두껍삼_강남직영점
# 한식, 두껍삼 강남직영점, 한우 숙성 부채살, 38,000원, 1973명
# https://map.naver.com/v5/search/두껍삼_강남직영점
# 한식, 두껍삼 강남직영점, 꽃살 (150g), 31,000원, 1973명
# https://map.naver.com/v5/search/두껍삼_강남직영점
# 한식, 두껍삼 강남직영점, 육회 (200g), 31,000원, 1973명
# https://map.naver.com/v5/search/두껍삼_강남직영점
# 한식, 두껍삼 강남직영점, 시골된장찌개, 4,000원, 1973명
# https://map.naver.com/v5/search/두껍삼_강남직영점
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13464/1060130730.py in <module>
#      68         select_btn = driver.find_element_by_css_selector('#_pcmap_list_scroll_container > ul > li:nth-child({}) > div._3hn9q > a > div.O9Z-o > div > span.OXiLu'.format(i))
#      69         select_btn.click()
# ---> 70         time.sleep(3)
#      71
#      72         #iframe을 옮기기 위한 코드
#
# KeyboardInterrupt:
